# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import seaborn as sns; sns.set()

import gensim
from sklearn.manifold import TSNE
import collections as collect
# Out:
# C:\Users\KETT\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
aisles = pd.read_csv("aisles.csv")
departments = pd.read_csv("departments.csv")
orders = pd.read_csv("orders.csv")
prior = pd.read_csv("order_products__prior.csv")
train = pd.read_csv("order_products__train.csv")
products = pd.read_csv("products.csv")

# %%
orders.head(100)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
# ...

# %%
len(orders.eval_set)
# Out:
# 3421083

# %%
len(orders.loc[orders['eval_set'] == 'prior'])
# Out:
# 3214874

# %%
# merge of DEPARTMENTS, AISLES, and PRODUCTS
stock = pd.merge(products, aisles, on = 'aisle_id')
stock.pop('aisle_id')
stock = pd.merge(stock, departments, on = 'department_id',  sort = False)
stock.pop('department_id')
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49688 entries, 0 to 49687
# Data columns (total 4 columns):
# product_id      49688 non-null int64
# product_name    49688 non-null object
# aisle           49688 non-null object
# department      49688 non-null object
# dtypes: int64(1), object(3)
# memory usage: 1.9+ MB

# %%
prior.tail()
# Out:
#           order_id product_id  add_to_cart_order  reordered
# 32434484   3421083        NaN                  6          1
# 32434485   3421083        NaN                  7          0
# 32434486   3421083        NaN                  8          0
# 32434487   3421083        NaN                  9          1
# 32434488   3421083        NaN                 10          1

# %%
# Out:
# order_id                    0
# product_id           31049872
# add_to_cart_order           0
# reordered                   0
# dtype: int64

# %%
train.sort_values(by=['user_id','order_number','add_to_cart_order'],inplace=True)
prior.sort_values(by=['user_id','order_number','add_to_cart_order'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-73009d20bcfd> in <module>
# ----> 1 train.sort_values(by=['user_id','order_number','add_to_cart_order'],inplace=True)
#       2 prior.sort_values(by=['user_id','order_number','add_to_cart_order'],inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4709
#    4710             keys = [self._get_label_or_level_values(x, axis=axis)
# -> 4711                     for x in by]
#    4712             indexer = lexsort_indexer(keys, orders=ascending,
#    4713                                       na_position=na_position)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in <listcomp>(.0)
#    4709
#    4710             keys = [self._get_label_or_level_values(x, axis=axis)
# -> 4711                     for x in by]
# ...
